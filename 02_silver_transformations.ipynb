-- %% [markdown]
-- ## 02_silver_transformations
-- ### Purpose: build Silver layer (clean, normalize, deduplicate)
-- Inputs: *__raw_
--
-- Outputs: *__clean_

-- %% [markdown]
-- ### Clients table

-- %%
CREATE OR REPLACE VIEW curso.ventas.clientes_clean AS
WITH 
base AS (
  SELECT
    id_cliente,

    -- Strings
    NULLIF(TRIM(nombre), '') AS nombre,
    NULLIF(TRIM(apellido), '') AS apellido,

    -- Normalización de sexo
    CASE
      WHEN LOWER(TRIM(sexo)) IN ('m', 'masculino') THEN 'M'
      WHEN LOWER(TRIM(sexo)) IN ('f', 'femenino')  THEN 'F'
      WHEN LOWER(TRIM(sexo)) IN ('otro') THEN 'O'
      ELSE NULL
    END AS sexo,

    -- Fecha nacimiento
    fecha_nacimiento,

    CURRENT_TIMESTAMP() AS cleaned_at
  FROM curso.ventas.clientes_raw
),

dedup AS (
  SELECT *
  FROM base
  WHERE id_cliente IS NOT NULL
  QUALIFY ROW_NUMBER() OVER (
    PARTITION BY id_cliente
    ORDER BY cleaned_at DESC
  ) = 1
)

SELECT id_cliente,
       nombre,
       apellido,
       sexo,
       fecha_nacimiento
FROM dedup;

-- %%
-- The view "curso.ventas.clientes_clean" must be created before querying it.
-- Run the CREATE OR REPLACE VIEW statement from Cell 2 first, then execute:

select * from curso.ventas.clientes_clean;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_cliente</th><th>nombre</th><th>apellido</th><th>sexo</th><th>fecha_nacimiento</th></tr></thead><tbody><tr><td>1</td><td>Irma</td><td>Agudo</td><td>F</td><td>1954-04-27</td></tr><tr><td>2</td><td>Calixto</td><td>Sosa</td><td>F</td><td>1958-12-27</td></tr><tr><td>3</td><td>Dionisia</td><td>Bonet</td><td>null</td><td>1977-04-13</td></tr><tr><td>4</td><td>Lupe</td><td>Martorell</td><td>M</td><td>1991-04-22</td></tr><tr><td>5</td><td>Ágata</td><td>Valls</td><td>M</td><td>1968-08-19</td></tr><tr><td>6</td><td>Cesar</td><td>Montes</td><td>null</td><td>1951-07-07</td></tr><tr><td>7</td><td>Eli</td><td>Gras</td><td>null</td><td>2002-11-16</td></tr><tr><td>8</td><td>Marcos</td><td>Canet</td><td>null</td><td>1973-06-09</td></tr><tr><td>9</td><td>Verónica</td><td>Abad</td><td>O</td><td>1998-02-04</td></tr><tr><td>10</td><td>Florencia</td><td>Arenas</td><td>M</td><td>1988-09-05</td></tr><tr><td>11</td><td>Diana</td><td>Lucas</td><td>O</td><td>1966-04-23</td></tr><tr><td>12</td><td>Piedad</td><td>Bonilla</td><td>M</td><td>1950-08-26</td></tr><tr><td>13</td><td>Tadeo</td><td>Cantero</td><td>F</td><td>1974-12-25</td></tr><tr><td>14</td><td>Flavia</td><td>Martín</td><td>O</td><td>1995-05-03</td></tr><tr><td>15</td><td>Pepe</td><td>Company</td><td>O</td><td>1992-07-16</td></tr><tr><td>16</td><td>Jordi</td><td>Nebot</td><td>O</td><td>2002
-- %% [markdown]
-- ### Products table

-- %%
CREATE OR REPLACE VIEW curso.ventas.productos_clean AS
WITH
base AS(
  SELECT
    id_producto,

    -- Strings
    NULLIF(REGEXP_REPLACE(TRIM(familia), '(?i)^null$', ''), '') AS familia,
    NULLIF(REGEXP_REPLACE(TRIM(nombre), '(?i)^null$', ''), '') AS nombre,

    precio_unitario,

    CURRENT_TIMESTAMP() AS cleaned_at
  FROM curso.ventas.productos_raw
),

dedup AS (
  SELECT *
  FROM base
  WHERE id_producto IS NOT NULL
  QUALIFY ROW_NUMBER() OVER(
    PARTITION BY id_producto
    ORDER BY cleaned_at DESC
  ) = 1
)

SELECT id_producto,
       familia,
       nombre,
       precio_unitario
FROM dedup;

-- %%
-- The view "curso.ventas.productos_clean" must be created before querying it.
-- Run the CREATE OR REPLACE VIEW statement from Cell 6 first, then execute:

SELECT * 
FROM curso.ventas.productos_clean;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_producto</th><th>familia</th><th>nombre</th><th>precio_unitario</th></tr></thead><tbody><tr><td>1</td><td>Leche</td><td>Leche</td><td>62</td></tr><tr><td>2</td><td>Leche</td><td>Nido</td><td>177</td></tr><tr><td>3</td><td>Leche</td><td>Klim</td><td>36</td></tr><tr><td>4</td><td>Leche</td><td>Nan Pro</td><td>156</td></tr><tr><td>5</td><td>Leche</td><td>Nestogeno</td><td>134</td></tr><tr><td>6</td><td>Leche</td><td>La lechera</td><td>68</td></tr><tr><td>7</td><td>Leche</td><td>Canprolac</td><td>36</td></tr><tr><td>8</td><td>Leche</td><td>Sativa 2,3</td><td>22</td></tr><tr><td>9</td><td>Leche</td><td>Nidina</td><td>247</td></tr><tr><td>10</td><td>Leche</td><td>Nan H.a.</td><td>149</td></tr><tr><td>11</td><td>Leche</td><td>Nan 2,3,4</td><td>159</td></tr><tr><td>12</td><td>Leche</td><td>Ideal</td><td>243</td></tr><tr><td>13</td><td>Leche</td><td>Desayuno Inteligente</td><td>36</td></tr><tr><td>14</td><td>Leche</td><td>Nutrición y Salud</td><td>154</td></tr><tr><td>15</td><td>Leche</td><td>Mi Vaca (descremada)</td><td>48</td></tr><tr><td>16</td><td>Leche</td><td>Svelty</td><td>179</td></tr><tr><td>17</td><td>Leche</td><td>Carnation</td><td>26</td></tr><tr><td>18</td><td>Leche</td><td>Leche Sur</td><td>58</td></tr><tr><td>19</td><td>Papillas</td><td>Papillas</td><td>149</td></tr><tr><td>20</td><td>Papillas</td><td>Nestum</td><td>242</td></tr><tr><td>21</td><td>Papillas</td><td>Papillas Nestlé 8 cereales</td><td>68</td></tr><tr><td>22</td><td>Papillas</td><td>Papillas Nestlé bífidus</td><td>85</td></tr><tr><td>23</td><td>Papillas</td><td>Papillas Nestlé Yogur</td><td>160</td></tr><tr><td>24</td><td>Cereales</td><td>Cereales</td><td>213</td></tr><tr><td>25</td><td>Cereales</td><td>Fitness</td><td>158</td></tr><tr><td>26</td><td>Cereales</td><td>Fitness Choc</td><td>243</td></tr><tr><td>27</td><td>Cereales</td><td>Fitness Dark Choc</td><td>70</td></tr><tr><td>28</td><td>Cereales</td><td>Fitness Choc White</td><td>176</td></tr><tr><td>29</td><td>Cereales</td><td>Fitness Choc Avellana</td><td>51</td></tr><tr><td>30</td><td>Cereales</td><td>Lion</td><td>161</td></tr><tr><td>31</td><td>Cereales</td><td>Chocapic</td><td>231</td></tr><tr><td>32</td><td>Cereales</td><td>Chocapic Avellana</td><td>130</td></tr><tr><td>33</td><td>Cereales</td><td>Cheerios</td><td>78</td></tr><tr><td>34</td><td>Cereales</td><td>Estrellitas</td><td>168</td></tr><tr><td>35</td><td>Cereales</td><td>Estrellita Maria</td><td>72</td></tr><tr><td>36</td><td>Cereales</td><td>Golden Grahams</td><td>113</td></tr><tr><td>37</td><td>Cereales</td><td>Cerelac</td><td>250</td></tr><tr><td>38</td><td>Cereales</td><td>Gold Flakes</td><td>34</td></tr><tr><td>39</td><td>Cereales</td><td>Nesquik</td><td>196</td></tr><tr><td>40</td><td>Cereales</td><td>Frosted Flakes</td><td>230</td></tr><tr><td>41</td><td>Cereales</td><td>Corn Flakes (sin Gluten)</td><td>50</td></tr><tr><td>42</td><td>Cereales</td><td>Nesquik Sin Gluten</td><td>181</td></tr><tr><td>43</td><td>Cereales</td><td>Milo</td><td>244</td></tr><tr><td>44</td><td>Cereales</td><td>Trix</td><td>130</td></tr><tr><td>45</td><td>Cereales</td><td>Nestum</td><td>10</td></tr><tr><td>46</td><td>Cereales</td><td>Zucosos (Chile)</td><td>174</td></tr><tr><td>47</td><td>Cereales</td><td>Cookie Crisp</td><td>213</td></tr><tr><td>48</td><td>Cereales</td><td>Lucky Charms</td><td>116</td></tr><tr><td>49</td><td>Barritas de Cereales</td><td>Barritas de Cereales</td><td>192</td></tr><tr><td>50</td><td>Barritas de Cereales</td><td>Barritas Golden Grahams</td><td>130</td></tr><tr><td>51</td><td>Barritas de Cereales</td><td>Barritas Nesquik</td><td>237</td></tr><tr><td>52</td><td>Barritas de Cereales</td><td>Barritas Chocapic</td><td>27</td></tr><tr><td>53</td><td>Barritas de Cereales</td><td>Barritas Fitness Choc</td><td>66</td></tr><tr><td>54</td><td>Barritas de Cereales</td><td>Barritas Fitness White</td><td>127</td></tr><tr> ...

-- %% [markdown]
-- ### Employees table

-- %%
CREATE OR REPLACE VIEW curso.ventas.empleados_clean AS
WITH
base AS(
  SELECT
    id_vendedor,

    sucursal,

    -- Strings
    NULLIF(REGEXP_REPLACE(TRIM(nombre), '(?i)^null$', ''), '') AS nombre,
    NULLIF(REGEXP_REPLACE(TRIM(apellido), '(?i)^null$', ''), '') AS apellido,

    CURRENT_TIMESTAMP() AS cleaned_at
  
    FROM curso.ventas.empleados_raw
),
dedup AS(
  SELECT *
  FROM base
  WHERE id_vendedor IS NOT NULL
el</td><td>Martínez</td></tr><tr><td>36</td><td>12</td><td>Ana</td><td>Pérez</td></tr><tr><td>37</td><td>14</td><td>Hector</td><td>null</td></tr><tr><td>38</td><td>10</td><td>Ramon</td><td>Gómez</td></tr><tr><td>39</td><td>8</td><td>Maria</td><td>Sánchez</td></tr><tr><td>40</td><td>5</td><td>Juan</td><td>Martínez</td></tr><tr><td>41</td><td>13</td><td>Jose</td><td>Pérez</td></tr><tr><td>42</td><td>1</td><td>Carlos</td><td>Álvarez</td></tr><tr><td>43</td><td>7</td><td>Jorge</td><td>Gómez</td></tr><tr><td>44</td><td>2</td><td>Luis</td><td>Sánchez</td></tr><tr><td>45</td><td>1</td><td>Hector</td><td>null</td></tr><tr><td>46</td><td>9</td><td>Ramon</td><td>Sánchez</td></tr><tr><td>47</td><td>11</td><td>Ramon</td><td>Rodríguez</td></tr><tr><td>48</td><td>14</td><td>Maria</td><td>González</td></tr><tr><td>49</td><td>1</td><td>Juan</td><td>García</td></tr><tr><td>50</td><td>11</td><td>Jose</td><td>López</td></tr><tr><td>51</td><td>14</td><td>Hector</td><td>null</td></tr><tr><td>52</td><td>5</td><td>Jorge</td><td>Álvarez</td></tr><tr><td>53</td><td>8</td><td>Luis</td><td>Gómez</td></tr><tr><td>54</td><td>8</td><td>Miguel</td><td>Sánchez</td></tr><tr><td>55</td><td>12</td><td>Ana</td><td>Rodríguez</td></tr><tr><td>56</td><td>13</td><td>Hector</td><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Shops table

-- %%
CREATE OR REPLACE VIEW curso.ventas.locales_clean AS
WITH base AS(
  SELECT
    id_sucursal,

    --Strings
    NULLIF(REGEXP_REPLACE(TRIM(nombre), '(?i)^null$', ''), '') as nombre,
    NULLIF(REGEXP_REPLACE(TRIM(tipo), '(?i)^null$', ''), '') as tipo,

    CURRENT_TIMESTAMP() AS cleaned_at
    
    FROM curso.ventas.locales_raw
),
dedup AS(
  SELECT * 
  FROM base
  WHERE id_sucursal IS NOT NULL
  QUALIFY ROW_NUMBER() OVER(
    PARTITION BY id_sucursal
    ORDER BY cleaned_at DESC
  ) = 1
)
SELECT id_sucursal,
       nombre,
       tipo
FROM dedup;

-- %%
-- The view "curso.ventas.locales_clean" must be created before querying it.
-- Run the CREATE OR REPLACE VIEW statement from Cell 12 first, then execute:

SELECT * 
FROM curso.ventas.locales_clean;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_sucursal</th><th>nombre</th><th>tipo</th></tr></thead><tbody><tr><td>1</td><td>Éxito Aranjuez</td><td>Supermercado</td></tr><tr><td>2</td><td>Éxito Aventura</td><td>Comercio de cercania</td></tr><tr><td>3</td><td>Éxito Belén</td><td>Supermercado</td></tr><tr><td>4</td><td>Éxito Colombia</td><td>Hipermercado</td></tr><tr><td>5</td><td>Éxito Del Este</td><td>Vecino</td></tr><tr><td>6</td><td>Éxito Envigado</td><td>Hipermercado</td></tr><tr><td>7</td><td>Éxito Envigado Centro</td><td>Supermercado</td></tr><tr><td>8</td><td>Éxito Gran Vía</td><td>Supermercado</td></tr><tr><td>9</td><td>Éxito Indiana Mall</td><td>Comercio de cercania</td></tr><tr><td>10</td><td>Éxito La Ceja</td><td>Comercio de cercania</td></tr><tr><td>11</td><td>Éxito La Central</td><td>Comercio de cercania</td></tr><tr><td>12</td><td>Éxito Itagüí</td><td>Supermercado</td></tr><tr><td>13</td><td>Éxito Junin</td><td>Supermercado</td></tr><tr><td>14</td><td>Éxito La 33</td><td>Supermercado</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Sales table (fact)

-- %%
CREATE OR REPLACE VIEW curso.ventas.facturas_clean AS
WITH base AS(
  SELECT
    -- String
    NULLIF(REGEXP_REPLACE(TRIM(num_factura), '(?i)^null$', ''), '') AS num_factura,
    
    fecha_venta,
    producto as id_producto, -- Aligning the column names with the other tables
    vendedor as id_vendedor,
    cliente as id_cliente,
    cantidad,

    CURRENT_TIMESTAMP() AS cleaned_at

    FROM curso.ventas.facturas_raw
),
dedup AS(
  SELECT *
  FROM base
  WHERE num_factura IS NOT NULL
  QUALIFY ROW_NUMBER() OVER(
    PARTITION BY num_factura
    ORDER BY cleaned_at DESC
  ) = 1
)
SELECT num_factura,
       fecha_venta,
       id_producto,
       id_vendedor,
       id_cliente,
       cantidad
FROM dedup;

-- %%
-- The view "curso.ventas.facturas_clean" must be created before querying it.
-- Run the CREATE OR REPLACE VIEW statement from Cell 15 first, then execute:

SELECT * 
FROM curso.ventas.facturas_clean
where fecha_venta = '2020-09-17';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_factura</th><th>fecha_venta</th><th>id_producto</th><th>id_vendedor</th><th>id_cliente</th><th>cantidad</th></tr></thead><tbody><tr><td>0056-14162468</td><td>2020-09-17</td><td>50</td><td>11</td><td>1628</td><td>60</td></tr><tr><td>0088-23433457</td><td>2020-09-17</td><td>89</td><td>51</td><td>1954</td><td>196</td></tr><tr><td>0215-54601762</td><td>2020-09-17</td><td>81</td><td>52</td><td>455</td><td>4</td></tr><tr><td>0758-09853600</td><td>2020-09-17</td><td>20</td><td>44</td><td>1060</td><td>112</td></tr><tr><td>0765-94932095</td><td>2020-09-17</td><td>26</td><td>30</td><td>195</td><td>116</td></tr><tr><td>0769-83720283</td><td>2020-09-17</td><td>74</td><td>26</td><td>2302</td><td>37</td></tr><tr><td>0883-67287261</td><td>2020-09-17</td><td>21</td><td>21</td><td>1025</td><td>176</td></tr><tr><td>1492-42941413</td><td>2020-09-17</td><td>14</td><td>33</td><td>951</td><td>165</td></tr><tr><td>1513-62273313</td><td>2020-09-17</td><td>69</td><td>35</td><td>673</td><td>148</td></tr><tr><td>1876-46486052</td><td>2020-09-17</td><td>14</td><td>29</td><td>1902</td><td>109</td></tr><tr><td>2111-82500563</td><td>2020-09-17</td><td>33</td><td>17</td><td>551</td><td>197</td></tr><tr><td>2261-94832580</td